# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
md_data = mouse_metadata.merge(study_results)

# Display the data table for preview
print(len(md_data))
# Out:
# 1893

# %%
# Checking the number of mice.



#
print(len((md_data['Mouse ID'].unique())))
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

md_data_cleaned = md_data.drop_duplicates(subset = ['Mouse ID', 'Timepoint'], keep = 'first')
md_data_cleaned

#for row in b['Count']:
    #if int(row) < 10:
        #print((row))


        
#pd.DataFrame(md_data, columns = ['Mouse ID', 'Timepoint'])

#meta_data_duplicates.duplicated()
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
md_data_clean1 = md_data.drop_duplicates(['Mouse ID'])
md_data_clean1
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
print(len((md_data_cleaned['Mouse ID'])))
# Out:
# 1888

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
md_data_cleaned.agg({'Tumor Volume (mm3)': ['var', 'std', 'mean', 'median']})

# This method is the most straighforward, creating multiple series and putting them all together at the end.
# Out:
#         Tumor Volume (mm3)
# var              79.291277
# std               8.904565
# mean             50.449276
# median           48.951421

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
bp = md_data_cleaned.groupby('Drug Regimen')
bpc = bp['Drug Regimen'].count()
#bpc = bp['Drug Regimen'].count()
bpc.plot.bar()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

bp_chart = bpc.plot(kind="bar", title="Mice by Regimen")
bp_chart.set_xlabel("Regimen")
bp_chart.set_ylabel("Number of Mice")
# Out:
# Text(0, 0.5, 'Number of Mice')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

mouse_gen = md_data_cleaned.groupby('Sex')

mg = mouse_gen['Sex'].count()
mg = pd.DataFrame(mg)


mg.plot.pie(y='Sex', figsize=(5, 5))

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
mg_chart = mg.plot(kind="pie",subplots=True, title="Mice by Sex")



#plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
#plt.title('My Title')
#plt.axis('equal')
#plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
mdd = md_data.groupby(['Mouse ID'])
mddg = pd.DataFrame(mdd['Timepoint'].max())

ackin = mddg.merge(md_data, on = ['Mouse ID'])

ackin = ackin.drop(columns = ['Timepoint_y'])
mddg = ackin.drop_duplicates('Mouse ID', keep = 'last')

a = pd.DataFrame(mddg[['Mouse ID', 'Drug Regimen', 'Timepoint_x', 'Tumor Volume (mm3)']])
a

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# Out:
#      Mouse ID Drug Regimen  Timepoint_x  Tumor Volume (mm3)
# 9        a203    Infubinol           45           67.973419
# 19       a251    Infubinol           45           65.525743
# 29       a262      Placebo           45           70.717621
# 39       a275     Ceftamin           45           62.999356
# 46       a366     Stelasyn           30           63.440686
# ...       ...          ...          ...                 ...
# 1852     z435     Propriva           10           48.710661
# 1862     z578     Ramicane           45           30.638696
# 1872     z581    Infubinol           45           62.754451
# 1882     z795     Naftisol           45           65.741070
# 1892     z969     Naftisol           45           73.867845
#
# [249 rows x 4 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)

tumvol = []
for row in a['Tumor Volume (mm3)']:
    
# Create empty list to fill with tumor vol data (for plotting)
    tumvol.append(row)

np.array(tumvol).astype(np.float)    
# Calculate the IQR and quantitatively determine if there are any potential outliers. 


quartiles = a['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of tumor volumes is: {lowerq}")
print(f"The upper quartile of tumor volumes is: {upperq}")
print(f"The interquartile range of tumor volumes is: {iqr}")
print(f"The the median of tumor volumes is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
fig1, ax1 = plt.subplots()
ax1.set_title('Drug Regimen by Last Timepoint')
ax1.set_ylabel('Tumor Volume')
ax1.boxplot(tumvol)
plt.show()
# Out:
# The lower quartile of tumor volumes is: 45.93471217
# The upper quartile of tumor volumes is: 64.95756185
# The interquartile range of tumor volumes is: 19.022849680000007
# The the median of tumor volumes is: 55.84141007
# Values below 17.400437649999986 could be outliers.
# Values above 93.49183637000002 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

####see above boxplot####

# %% [markdown]
# ## Line and Scatter Plots

# %%
b = md_data.loc[md_data['Drug Regimen'] == 'Capomulin']
b
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# ...

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
md_data.dtypes
# Out:
# Mouse ID               object
# Drug Regimen           object
# Sex                    object
# Age_months              int64
# Weight (g)              int64
# Timepoint               int64
# Tumor Volume (mm3)    float64
# Metastatic Sites        int64
# dtype: object

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
md_data.plot(kind="scatter", x="Weight (g)", y="Tumor Volume (mm3)", grid=True, figsize=(8,8),
              title="Weight Vs. Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
md_data.dropna()
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
weight = md_data.iloc[:5]
avgtumorv = md_data.iloc[:7]

correlation = st.pearsonr(weight, avgtumorv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-415-788149e01e16> in <module>
#       2 avgtumorv = md_data.iloc[:7]
#       3
# ----> 4 correlation = st.pearsonr(weight, avgtumorv)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3496     We use this table to find the p-value:
#    3497
# -> 3498     >>> import scipy.stats as stats
#    3499     >>> oddsratio, pvalue = stats.fisher_exact([[8, 2], [1, 5]])
#    3500     >>> pvalue
#
# ValueError: x and y must have the same length.
